# %% [markdown]
# <a href="https://colab.research.google.com/github/Tush2203/Data-Analysis/blob/main/Wine_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df2 = pd.read_csv('/content/winequalityN.csv')
df2.head(2)

# %%
sns.distplot(df2['fixed acidity'])

# %%
sns.jointplot(data=df2,x='type',y='quality',height=4)

# %%
sns.jointplot(data=df2,x='alcohol',y='quality',height=4,hue='type')

# %%
# ?sns.jointplot

# %%
#sns.pairplot(df2,hue='type')

# %%
sns.countplot(x='quality',data=df2,hue='type')

# %%
sns.barplot(x='type',y='quality',data=df2,hue='type')

# %%
# ?sns.barplot

# %%
sns.scatterplot(data=df2,x='alcohol',y='residual sugar',hue='type')

# %%
sns.boxplot(data=df2,x='quality',y='alcohol',hue='type',order=[9,7,6,8,5,4,3],showmeans=True,
            meanprops={'marker':'+','markeredgecolor':'yellow'},palette="cool")

# %%
var = sns.load_dataset('tips')
var.head()

# %%
sns.violinplot(x='quality',y='alcohol',data=df2,linewidth=.9,palette='dark',hue='type',split=True,scale='width',inner='quart')

# %%
# ?sns.violinplot

# %%
sns.violinplot(x='quality',data=df2)

# %%
var = df2.iloc[1:,1:].corr()
var

# %%
sns.heatmap(var,annot=True)

# %%
v = df2.pivot_table(values=['quality'],
                   index = 'alcohol',
                   aggfunc = {'alcohol':['max','min'],
                              'quality':['max','min']})
sns.heatmap(v)

# %%
sns.lmplot(x='quality',y='alcohol',data=df2,hue='type',markers=['o','+'])

# %%
sns.lmplot(x='quality',y='alcohol',data=df2,row='type',col='quality')
